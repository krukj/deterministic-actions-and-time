# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")

from src.action import Action
from src.program import Program
from src.queries import query_Q1, query_Q2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Example: Tatra mountains

# %%
fluents = ["in_kuznice", "has_money", "tired", "on_the_mountain"]

cable_car_ride = Action(
    preconditions={"has_money": True, "in_kuznice": False},
    effects={"on_the_mountain": True},
    duration=1,
)

hike = Action(
    preconditions={"in_kuznice": False},
    effects={"on_the_mountain": True, "tired": True},
    duration=3,
)

program = Program(actions=[cable_car_ride])

pi = {
    "in_kuznice": True,
    "tired": False,
    "on_the_mountain": False,
}  # has_money True or False

goal = {"on_the_mountain": True}

print("Q1 (Value Query): ", query_Q1(pi, program, goal, fluents))
print("Q2 (Time Query): ", query_Q2(pi, program, 1, fluents))
# Out:
# Q1 (Value Query):  True
# Q2 (Time Query):  True
